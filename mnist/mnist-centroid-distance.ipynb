# %%
from collections import Counter
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Plot a sample distance between clusters
plt.rcParams.update({'font.size': 14})


colnames = [ i for i in range(32)]
df_distmatrix = pd.read_csv("./mnist_32_distances.csv", names=colnames, header=None)
plt.rcParams['figure.figsize'] = [28, 28]
plt.rcParams['figure.dpi'] = 200 # 200 e.g. is really fine, but slower
#sns.heatmap(df_distmatrix, cmap='rocket', robust=True) #,  xticklabels=True, yticklabels=True, linewidth=1, linecolor='b', robust=True, vmin=0, vmax=32000, annot=True, fmt='.0f'
sns.heatmap(df_distmatrix, cmap='Blues', vmin=0, vmax=3, annot=True, fmt='.2f') #,  xticklabels=True, yticklabels=True, linewidth=1, linecolor='b', robust=True, vmin=0, vmax=32000, annot=True, fmt='.00f'
#plt.show()
plt.savefig('../mnist_cluster_32_small.png', format='png', dpi=200)
